# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 kB 23.4 MB/s eta 0:00:00
# ...

# %%
## importing required libraries
import os
import shutil
import random

# !pip install tqdm --upgrade
from tqdm.notebook import tqdm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 4.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.6
#     Uninstalling tqdm-4.66.6:
#       Successfully uninstalled tqdm-4.66.6
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="vhuhQ5id2ui3NSMKgzPl")
project = rf.workspace("capstone-project-1").project("dataset-v4-x5rbk")
version = project.version(3)
dataset = version.download("yolov5")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to dataset-v4-3 in yolov5pytorch:: 100%|██████████| 10300/10300 [00:01<00:00, 6370.80it/s]

# %%
## connecting to the google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#roboflow project datasets.
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="vhuhQ5id2ui3NSMKgzPl")
project = rf.workspace("capstone-project-1").project("dataset2-9f0jj")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Dependency ultralytics==8.0.196 is required but found version=8.3.3, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to dataset2-2 in yolov8:: 100%|██████████| 244/244 [00:00<00:00, 6127.32it/s]

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.34 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.5/107.7 GB disk)

# %%
# !yolo task=detect mode=train data=/content/dataset-v4-3/data.yaml epochs=100 imgsz=255 batch=32 patience=5 project=/content/drive/MyDrive/yolov10s/training_results name=cornViabilityFinal103
# Out:
# Ultralytics 8.3.34 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov10s/training_results/cornViabilityFinal103/weights/best.pt conf=0.55 source=/content/dataset-v4-3/test/images
# Out:
# Ultralytics 8.3.34 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/224 /content/dataset-v4-3/test/images/Img00161_png.rf.70986b07e093f6b0aa44582fc691f6e6.jpg: 256x256 4 Less Viables, 12.9ms
# image 2/224 /content/dataset-v4-3/test/images/Img00161_png.rf.733374336415cb4c358d41a41cc52502.jpg: 256x256 7 Less Viables, 9.4ms
# image 3/224 /content/dataset-v4-3/test/images/Img00161_png.rf.a452a5e6a2ebb1a52274a82e76974d1b.jpg: 256x256 3 Less Viables, 8.2ms
# image 4/224 /content/dataset-v4-3/test/images/Img00161_png.rf.e6bc99fdac2c12b5378db7f9e90709a5.jpg: 256x256 7 Less Viables, 8.0ms
# image 5/224 /content/dataset-v4-3/test/images/Img00241_png.rf.061af0672c6cf01fc52495bd50937dbd.jpg: 256x256 3 Less Viables, 8.4ms
# image 6/224 /content/dataset-v4-3/test/images/Img00241_png.rf.602634f45e77521c291314a86d7ad2e7.jpg: 256x256 7 Less Viables, 8.5ms
# ...

# %%
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/yolov8/output

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov10s/training_results/cornViabilityFinal103/weights/best.pt conf=0.55 source=/content/drive/MyDrive/Viable2.MP4
# Out:
# Ultralytics 8.3.34 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# video 1/1 (frame 1/1394) /content/drive/MyDrive/Viable2.MP4: 160x256 23 Non-viables, 80.8ms
# video 1/1 (frame 2/1394) /content/drive/MyDrive/Viable2.MP4: 160x256 23 Non-viables, 13.5ms
# video 1/1 (frame 3/1394) /content/drive/MyDrive/Viable2.MP4: 160x256 22 Non-viables, 13.2ms
# video 1/1 (frame 4/1394) /content/drive/MyDrive/Viable2.MP4: 160x256 23 Non-viables, 13.8ms
# video 1/1 (frame 5/1394) /content/drive/MyDrive/Viable2.MP4: 160x256 24 Non-viables, 12.7ms
# video 1/1 (frame 6/1394) /content/drive/MyDrive/Viable2.MP4: 160x256 22 Non-viables, 13.2ms
# video 1/1 (frame 7/1394) /content/drive/MyDrive/Viable2.MP4: 160x256 24 Non-viables, 13.9ms
# video 1/1 (frame 8/1394) /content/drive/MyDrive/Viable2.MP4: 160x256 24 Non-viables, 12.8ms
# ...

# %%
#  Export model to tflite


from ultralytics import YOLO

# Load a model
model = YOLO('/content/drive/MyDrive/yolov10s/training_results/cornViabilityFinal103/weights/best.pt')  # load a custom trained model

# Export the model
model.export(format='tflite')
# Out:
# Ultralytics 8.3.34 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/yolov10s/training_results/cornViabilityFinal103/weights/best.pt' with input shape (1, 3, 256, 256) BCHW and output shape(s) (1, 7, 1344) (5.2 MB)
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'onnx>=1.12.0', 'onnx2tf>1.17.5,<=1.22.3', 'onnxslim>=0.1.31', 'tflite_support', 'onnxruntime'] not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.6/136.6 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 140.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 186.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.0/435.0 kB 187.2 MB/s eta 0:00:00
# ...

# %%
# Prediction using custom tflite model

#  Prediction using trained model

from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('/content/cornViabilityV2_saved_model/cornViabilityV2_float32.tflite')

# Run inference
model.predict('/content/sweetViable06801.png', save=True, imgsz=640, conf=0.6)
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading /content/cornViabilityV2_saved_model/cornViabilityV2_float32.tflite for TensorFlow Lite inference...
#
# image 1/1 /content/sweetViable06801.png: 640x640 1 Less Viable, 19 Viables, 407.8ms
# Speed: 183.6ms preprocess, 407.8ms inference, 75.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict6
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Less Viable', 1: 'Non-viable', 2: 'Viable'}
#  obb: None
#  orig_img: array([[[155, 155, 150],
#          [154, 154, 148],
#          [158, 155, 150],
#          ...,
#          [144, 143, 140],
#          [144, 144, 138],
#          [144, 144, 138]],
#
#         [[157, 157, 151],
#          [157, 157, 151],
# ...
